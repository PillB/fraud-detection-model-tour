# %% [markdown]
# # Fraud Detection Model Tour - Run All Examples Online
#
# This notebook runs the lightweight Python examples used by the website: supervised baselines, anomaly detectors, VAE proxy, sequence proxy, graph models, GraphRAG, entity resolution, and the comparison harness.
#
# The examples use synthetic data only. They are educational proxies designed to run in Colab without private data or heavy production infrastructure.

# %%
# !git clone https://github.com/PillB/fraud-detection-model-tour.git
# %cd fraud-detection-model-tour
# !pip install -q -r requirements.txt

# %%
# !python experiments/run_all_model_examples.py

# %%
from IPython.display import Markdown, Image, display
display(Markdown(open('experiments/all_model_examples_summary.md').read()))
display(Image('experiments/all_model_examples_summary.png'))

# %% [markdown]
# ## Run One Model Family
#
# Use these commands for focused runs:
#
# ```bash
# python experiments/toy_isolation_forest.py
# python experiments/toy_supervised_baselines.py
# python experiments/toy_density_outlier_suite.py
# python experiments/toy_graph_link_prediction.py
# python experiments/toy_entity_resolution.py
# python experiments/compare_models.py
# ```
#
# Production upgrades such as PyOD, PyTorch Geometric, DGL, LightGBM, CatBoost, or full temporal GNNs are documented in the model cards but kept optional so this notebook stays runnable.
